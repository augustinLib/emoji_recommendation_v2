# %%
import pandas as pd
import numpy as np

# %%
senti_df = pd.read_excel("../data/sentimental_data/Training/감성대화말뭉치(최종데이터)_Training.xlsx")

# %%
senti_df2 = pd.read_excel("../data/sentimental_data/Validation/감성대화말뭉치(최종데이터)_Validation.xlsx")

# %%
senti_df.head(20)
# Out:
#        번호   연령  성별         상황키워드    신체질환 감정_대분류       감정_소분류  \
# 0   44164   청년  남성    연애, 결혼, 출산    해당없음     기쁨         신이 난
# 1    3926   노년  남성        건강, 죽음  만성질환 유     불안      스트레스 받는
# 2   50882  청소년  여성       학업 및 진로    해당없음     당황           당황
# 3   31303   노년  남성            재정  만성질환 무     기쁨         신이 난
# 4   47200   노년  여성            재정  만성질환 유     기쁨           안도
# 5   48610   중년  여성  재정, 은퇴, 노후준비    해당없음     불안          취약한
# 6   17198   중년  남성            건강    해당없음     슬픔          우울한
# 7   12186   노년  남성            재정  만성질환 무     분노       구역질 나는
# 8   35975  청소년  남성      학교폭력/따돌림    해당없음     분노          좌절한
# 9   12551   노년  여성          대인관계  만성질환 무     슬픔       눈물이 나는
# 10  31529   노년  남성        건강, 죽음  만성질환 무     상처         배신당한
# 11  42590  청소년  남성       학업 및 진로    해당없음     당황  남의 시선을 의식하는
# 12  14406   중년  여성  재정, 은퇴, 노후준비    해당없음     당황         죄책감의
# 13  34944   중년  남성            건강    해당없음     불안        당혹스러운
# 14   1679   노년  여성        건강, 죽음  만성질환 유     기쁨           안도
# 15  41642   청년  여성    연애, 결혼, 출산    해당없음     분노           분노
# 16  35528   청년  여성          대인관계    해당없음     불안          두려운
# 17  39736   노년  남성            재정  만성질환 무     분노          좌절한
# 18  30998   노년  여성        건강, 죽음  만성질환 무     슬픔          낙담한
# 19  10902  청소년  남성       학업 및 진로    해당없음     불안         회의적인
#
#                                                 사람문장1  \
# 0                           아내가 드디어 출산하게 되어서 정말 신이 나.
# 1             당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.
# 2             고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.
# 3       재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.
# 4                        빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.
# 5   이제 곧 은퇴할 시기가 되었어. 내가 먼저 은퇴를 하고 육 개월 후에 남편도 은퇴를...
# 6                       사십 대에 접어들면서 머리카락이 많이 빠져 고민이야.
# 7                                      이제 돈이라면 지긋지긋해.
# 8              친구들이 나를 괴롭혀. 부모님과 선생님께 얘기했는데도 믿어주지 않아.
# 9                                        친구 때문에 눈물 나.
# 10  새로 간 치과에서 조금 썩기만 한 이를 임플란트를 하라고 했어. 과잉진료는 안 한다더니.
# 11    오늘 선생님이 나보고 앞에 나와 문제를 풀어보라고 했는데 답을 외워서 문제를 풀었어.
# 12           내가 무능해서 자기가 좋은 대학에 못 들어갔다는 딸의 말을 듣고 괴로워.
# 13                    아내의 건강이 갑자기 악화됐어. 너무 걱정스럽고 불안해.
# 14       남편이 죽기 전에 손자들 얼굴 보고 싶다고 했는데 다행히 늦지 않아서 안도했어.
# 15  날 좋아하는 남자애가 내 생일에 케이크을 선물해 주고는 친구들한테 나랑 사귄다고 소...
# 16          이번에도 고시에 불합격했어. 부모님께 무슨 소리를 들을지 벌써부터 두려워.
# 17             내가 일할 수 있는 자리가 점점 줄어든다는 걸 생각하니 너무 속상해.
# 18                 남편과 건강하게 오랫동안 살고 싶은데 남편이 당뇨병에 걸렸다.
# 19                                공부를 해도 성적이 오르지 않아.
#
#                                              시스템응답1  \
# 0                         아내분이 출산을 하시는군요. 정말 축하드려요.
# 1                                약 종류가 많아 번거로우시겠어요.
# 2           고등학교 수업이 중학교 때와는 다르게 갑자기 어려워서 당황스러우시군요.
# 3                           재취업 후 첫 월급이라 정말 기쁘시겠어요.
# 4                    기분 좋으시겠어요. 앞으로는 어떻게 하실 생각이신가요?
# 5   그러시군요. 은퇴 후 남편분과 함께 집에 있을 생각을 하니 막막한 기분이 드시는군요.
# 6                             머리카락이 빠져서 걱정이 많으시겠어요.
# 7                                       무슨 일 있으셨나요?
# 8     괴롭힘을 당해 힘든데도 부모님과 선생님께서 믿어주지 않아서 정말 마음 아프겠네요.
# 9                       친구 때문에 눈물이 나시는군요. 무슨 일이세요?
# 10          이가 조금 썩기만 했는데도 임플란트를 해야 한다고 했다는 말씀이시군요.
# 11                                 답을 외워서 문제를 풀었군요.
# 12                        딸의 원망에 당황스럽고 죄책감을 느끼셨겠군요.
# 13                 아내 분의 건강이 급작스레 악화되셔서 많이 불안하시겠네요.
# 14                 남편분이 죽기 전에 소망을 이뤄서 다행이라 생각하시는군요.
# 15                                 그래서 어떤 기분이 드셨나요?
# 16             부모님께 고시에 불합격했다고 하면 무슨 소리를 들을지 두렵겠어요.
# 17                                  일자리 때문에 속상하시군요.
# 18                         남편이 당뇨병에 걸려서 속상하고 슬프겠어요.
# 19                              공부를 했는데도 오르지 않는가요.
#
#                                                 사람문장2  \
# 0                                       아 지금 정말 신이 나.
# 1                         건강할 때 관리 좀 잘할걸 하는 생각이 들더라고.
# 2                   아직 학기 초인데 내가 수업에 잘 따라갈 수 있을지 걱정돼.
# 3   퇴직 후 다시는 돈을 못 벌 줄 알았는데 이렇게 월급으로 가족에게 맛있는 밥을 살 ...
# 4                   빚도 다 갚았으니 당분간은 아무 생각도 안 하며 살고 싶어.
# 5   둘이서 같이 뭘 해본 적이 없거든. 앞으로 백 세시대라고 하는데 어떻게 지내야 할지...
# 6                               이러다 대머리가 되지 않을까 걱정이야.
# 7                        나이가 예순이 넘으니 돈이 나갈 데도 많고 힘드네.
# 8                       너무 화도 나고 좌절한 상태야. 학교 다니기가 싫어.
# 9                                    내 친구가 나한테 거짓말했어.
# 10  예전에 다니던 치과에서는 심하지 않은 충치니까 관리만 하라고 했는데 말이야. 오히려...
# 11  칠판 앞까지 나가서 답을 틀리면 다들 나를 비웃을 게 뻔하니까. 그래서 답을 보고 ...
# 12                    엄마로서 딸에게 해 준 게 하나도 없는 것 같아 괴로워.
# 13                               나 혼자 남으면 어떻게 살지 막막해.
# 14      살아서도 아주 예뻐하던 손자들인데 꼭 보고 싶다고 하니 마음에 걸렸는데 다행이야.
# 15                               내 속에서 분노가 치밀어 오르더라고.
# 16                                 거짓말이라도 하고 싶은 심정이야.
# 17                기계는 계속 발달하고 경제는 날마다 안 좋아지니 정말 걱정이야.
# 18                   원래 고혈압 질환이 있었는데 이번에 당뇨병까지 걸린 거야.
# 19               성적이 오르지도 않는데 공부를 꼭 해야 하나 하는 생각이 들어.
#
#                                                시스템응답2  \
# 0                                           잘 된 일이네요.
# 1                       현재 상황에서 변화를 주기 위해 어떻게 하면 될까요?
# 2                         이 상황에서 할 수 있는 게 어떤 것이 있을까요?
# 3                             이 기분을 유지하려면 어떻게 해야 할까요?
# 4                빚도 다 갚았으니 당분간은 아무 생각도 안 하며 살고 싶으시군요.
# 5   남편과 뭔가를 같이 해본 적이 없어서 걱정이 되시는군요. 남편분과 시간을 같이 보낼...
# 6                                    병원에서 진료는 받아보셨나요?
# 7                            돈이 나갈 곳이 많아 재정적으로 힘드시군요.
# 8                     마음이 어려우실 것 같아요. 어떻게 하는 것이 좋을까요?
# 9                                거짓말한 친구 때문에 속상하셨겠네요.
# 10  새 치과가 과잉 진료를 하는 것 같아 믿음이 안 가시는군요. 이 상황에서 앞으로 어...
# 11                               친구들의 시선이 신경쓰이셨던 거군요.
# 12                         엄마로서 딸을 잘 못 챙겨준 것 같아 괴롭군요.
# 13  나 혼자 남으면 어떻게 살지 막막하군요. 이 상황에서 할 수 있는 일에는 무엇이 있...
# 14                     이런 일이 생기면 어떻게 하면 될지 계획이 있으신가요?
# 15                          남자애가 허위 소문을 퍼뜨려서 화가 나셨군요.
# 16                        어떻게 하면 불안한 기분에서 벗어날 수 있을까요?
# 17                                이 상황에 어떻게 대처해야 할까요?
# 18                          고혈압과 당뇨병 치료에 좋은 방법이 있을까요?
# 19                          성적이 오르지 않으면 그런 생각이 드는군요.
#
#                                                 사람문장3  \
# 0                  아기가 점점 클게 벌써 기대가 되네. 내가 많이 놀아줘야지.
# 1                          약을 잘 챙겨 먹고 나을 수 있도록 노력해야지.
# 2                       중학교 수업을 들을 때보다 훨씬 더 열심히 할 거야.
# 3                           회사생활을 열심히 해서 계속 월급을 받을거야!
# 4                                                 NaN
# 5                                함께 등산이나 여행을 갔으면 좋겠어.
# 6                   아직 병원 진료는 받지 않았고 탈모방지용 샴푸를 쓰고 있어.
# 7                                                 NaN
# 8                증거를 준비해서 다시 부모님과 선생님께 말씀 드리는 것이 좋겠어.
# 9                                                 NaN
# 10             좀 멀어도 이사 오기 전에 살던 동네의 믿을만한 옛 치과를 가야겠어.
# 11  문제는 틀릴 수도 있는 거라고 생각하면서도 자꾸 남들을 의식하게 돼. 형한테 얘기해볼까.
# 12             물론 나는 열심히 노력했지만 딸에게 그렇게 받아들여졌다면 그런 거지.
# 13                         아무래도 자식들에게는 미리 말해놓는 게 좋겠어.
# 14         내가 생명이 위급하면 가족 모두를 불러서 다 한 번씩 보고 가도록 할 거야.
# 15                    내일 그 남자애한테 소문을 바로잡고 사과하라고 해야겠어.
# 16  말하지 않고 숨기면 후일 더 큰 폭풍으로 돌아올 수 있어. 어쩔 수 없이 직접 말씀...
# 17          전문직으로 일할 수 있는 분야를 공부하려고. 내가 살 길은 내가 찾아야지.
# 18          병원에서 권해주는 약을 잘 먹고 몸에 해로운 음식은 먹지 않는 게 좋겠어.
# 19                                                NaN
#
#                                           시스템응답3  \
# 0                   좋은 아빠가 되실 거 같아요. 진심으로 축하드려요.
# 1                        약을 잘 챙겨 먹어 건강해지시길 바랄게요.
# 2                     수업을 어떤 방식으로 열심히 듣는게 좋을까요?
# 3                    계속 원하시는 대로 회사생활이 이어지길 바랄게요.
# 4                                            NaN
# 5                     남편분과 함께 등산이나 여행을 가고 싶으시군요.
# 6                    모발 건강을 위해 더 할 수 있는 일이 있을까요?
# 7                                            NaN
# 8             네. 꼭 증거를 통해 부모님과 선생님께서 믿어주시면 좋겠어요.
# 9                                            NaN
# 10                     믿을만한 치과에서 진료가 잘 되기를 바랄게요.
# 11          형과의 대화를 통해 지금의 기분과 상황이 조금 좋아지길 바랄게요.
# 12                     그래도 나는 딸을 위해 진심으로 노력했었군요.
# 13                       자녀 분들에게 미리 말해 두려 하시는군요.
# 14                           계획한 대로 잘 실천되면 좋겠어요.
# 15                         내일 그 남자애한테 말할 생각이시군요.
# 16                 숨기지 않고 지금 직접 말씀드리기로 마음 먹으셨군요.
# 17          친구들과 진솔한 대화를 통해 기분이 나아질 수 있었으면 좋겠어요.
# 18  몸에 해로운 음식을 먹지 않는 게 질병의 치료에 많은 효과가 있었으면 좋겠어요.
# 19                                           NaN
#
#                                         사람문장4                    시스템응답4
# 0                                         NaN                       NaN
# 1                                         NaN                       NaN
# 2   선생님이 강조하신 부분을 필기하고 집에서 매일 수업 내용을 복습하려고 해.  열심히 해서 좋은 결과가 있었으면 좋겠어요.
# 3                                         NaN                       NaN
# 4                                         NaN                       NaN
# 5                                         NaN                       NaN
# 6                                         NaN                       NaN
# 7                                         NaN                       NaN
# 8                                         NaN                       NaN
# 9                                         NaN                       NaN
# 10                                        NaN                       NaN
# 11                                        NaN                       NaN
# 12                                        NaN                       NaN
# 13                                        NaN                       NaN
# 14                                        NaN                       NaN
# 15                                        NaN                       NaN
# 16                                        NaN                       NaN
# 17                                        NaN                       NaN
# 18                                        NaN                       NaN
# 19                                        NaN                       NaN

# %%
senti_df.shape
# Out:
# (40879, 15)

# %%
senti_df["사람문장2"].isna().sum()
# Out:
# 0

# %% [markdown]
# ## 감정_대분류 기준으로 label 분류

# %% [markdown]
# ### 중복 제거(같은 감정이지만 공백으로 인해 다르게 인식되는 항목들 병합)

# %%
set(senti_df["감정_대분류"])
# Out:
# {'기쁨', '기쁨 ', '당황', '분노', '불안', '불안 ', '상처', '슬픔'}

# %%
set(senti_df2["감정_대분류"])
# Out:
# {'기쁨', '당황', '분노', '불안', '상처', '슬픔'}

# %%
# 띄어쓰기 되어있는 label변경
senti_df = senti_df.replace({'감정_대분류' : '기쁨 '}, '기쁨')
senti_df = senti_df.replace({'감정_대분류' : '불안 '}, '불안')

# %%
set(senti_df["감정_대분류"])
# Out:
# {'기쁨', '당황', '분노', '불안', '상처', '슬픔'}

# %%
def unzip_sentence(df):
    unzipped_x = []
    unzipped_y = []
    for i in range(len(df)):
        # 사람문장 1
        unzipped_x.append(df.iloc[i, 7])
        unzipped_y.append(df.iloc[i, 5])
        # 사람문장 2
        unzipped_x.append(df.iloc[i, 9])
        unzipped_y.append(df.iloc[i, 5])

    unzipped_dict = {"sentences" : unzipped_x, "sentiment" : unzipped_y}
    unzipped_df = pd.DataFrame(unzipped_dict)

    return unzipped_df

# %%
senti1_unzipped = unzip_sentence(senti_df)

# %%
senti2_unzipped = unzip_sentence(senti_df2)

# %%
senti1_unzipped.head(10)
# Out:
#                                            sentences sentiment
# 0                          아내가 드디어 출산하게 되어서 정말 신이 나.        기쁨
# 1                                      아 지금 정말 신이 나.        기쁨
# 2            당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.        불안
# 3                        건강할 때 관리 좀 잘할걸 하는 생각이 들더라고.        불안
# 4            고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.        당황
# 5                  아직 학기 초인데 내가 수업에 잘 따라갈 수 있을지 걱정돼.        당황
# 6      재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.        기쁨
# 7  퇴직 후 다시는 돈을 못 벌 줄 알았는데 이렇게 월급으로 가족에게 맛있는 밥을 살 ...        기쁨
# 8                       빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.        기쁨
# 9                  빚도 다 갚았으니 당분간은 아무 생각도 안 하며 살고 싶어.        기쁨

# %%
senti2_unzipped.head(10)
# Out:
#                                            sentences sentiment
# 0                                    요즘 부모님과 많이 부딪혀.        분노
# 1  난 하고 싶은 일이 있는데 부모님은 안정적인 일만 하라고 하셔. 내 마음대로 하지도...        분노
# 2                           엄마가 결국 집을 나갔어. 너무 너무 슬퍼.        슬픔
# 3  엄마도 엄마만의 인생이 있을 테니 가지 말라고 할 수가 없었어. 그래서 더 마음이 ...        슬픔
# 4                     학교에서 한 친구를 괴롭히는 무리에게 그만하라고 했어.        불안
# 5                      그런데 말을 하고 난 후 나도 괴롭힐까 봐 불안했어.        불안
# 6   이번에 팀장님이 간단한 조사 업무를 부탁하셨는데 내가 잘못 처리했어. 너무 절망적이야.        당황
# 7               곧 있으면 인턴에서 정규직 전환 평가가 있는데 안 좋을 것 같아.        당황
# 8                  남편이 이혼할 때 위자료를 주지 않으려고 변호사를 고용했어.        분노
# 9                             어떻게 그럴 수가 있지? 너무 화가 나.        분노

# %%
senti_unzipped = senti1_unzipped.(senti2_unzipped)
# Out:
# /var/folders/ss/fc84jp2j3s7cg71690xjt3g40000gn/T/ipykernel_9400/1392044925.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   senti_unzipped = senti1_unzipped.append(senti2_unzipped)

# %%
senti_unzipped.shape
# Out:
# (92018, 2)

# %%
senti_unzipped.to_csv("../data/sentimental.csv")
